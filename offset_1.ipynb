# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.genfromtxt('blu_1.1_1.35_1.45_1.7_25_1.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='o')

data = np.genfromtxt('blu_1.1_1.35_1.45_1.7_25_2.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='^')

data = np.genfromtxt('blu_1.1_1.35_1.45_1.7_25_3.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='s')

plt.title("xcube sample 1")
plt.show() # Optional in modern Jupyter as plots auto-render

# %%
data = np.genfromtxt('blu_1.1_1.4_1.4_1.7_25_1.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='o')

data = np.genfromtxt('blu_1.1_1.4_1.4_1.7_25_2.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='^')

data = np.genfromtxt('blu_1.1_1.4_1.4_1.7_25_3.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='s')

plt.title("xcube sample 1")
plt.show() # Optional in modern Jupyter as plots auto-render

# %%
data = np.genfromtxt('blu_1.0_1.4_1.4_1.8_25_1.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='o')

data = np.genfromtxt('blu_1.0_1.4_1.4_1.8_25_2.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='^')

data = np.genfromtxt('blu_1.0_1.4_1.4_1.8_25_3.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='s')

plt.title("xcube")
plt.show() # Optional in modern Jupyter as plots auto-render

# %%
data = np.genfromtxt('blu2_ref_1.0_1.4_1.4_1.8_25_1.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='o')

data = np.genfromtxt('blu2_ref_1.0_1.4_1.4_1.8_25_2.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='^')

data = np.genfromtxt('blu2_ref_1.0_1.4_1.4_1.8_25_3.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='s')

data = np.genfromtxt('blu2_ref_1.0_1.4_1.4_1.8_25_4.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='+')

data = np.genfromtxt('blu2_ref_1.0_1.4_1.4_1.8_25_5.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='*')

data = np.genfromtxt('blu2_ref_1.0_1.4_1.4_1.8_25_6.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='D')

data = np.genfromtxt('blu2_ref_1.0_1.4_1.4_1.8_25_7.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
plt.plot(data['position'], data['distance'], marker='x')

# data = np.genfromtxt('blu2_ref_1.6_1.9_1.9_2.3_25_1.csv', delimiter=',', names=True, dtype=None, encoding='utf-8')
# plt.plot(data['position'], data['distance'])

plt.title("xcube reference")
plt.show() # Optional in modern Jupyter as plots auto-render
